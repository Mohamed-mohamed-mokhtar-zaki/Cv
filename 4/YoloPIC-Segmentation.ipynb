# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
model = YOLO("yolov8n-seg.pt")
results = model(r"C:\Users\DELL\Desktop\test\image1.jpg")
result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()
# Out:
# image 1/1 C:\Users\DELL\Desktop\test\image1.jpg: 512x640 1 cat, 1 dog, 171.5ms
# Speed: 3.0ms preprocess, 171.5ms inference, 11.0ms postprocess per image at shape (1, 3, 512, 640)

# %%
from ultralytics import YOLO
import cv2

# %%
model = YOLO("yolov8n-seg.pt")

# %%
video_path = r"C:\Users\DELL\Desktop\test\vibes.MOV"
output_video_path = r'C:\Users\DELL\Desktop\test\output_Vibs.MOV'

# %%
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print("لا يمكن فتح الفيديو. تحقق من المسار.")
    exit()

# %%
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))  
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) 
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# %%
while True:
    ret, frame = cap.read()
    if not ret:
        break
    results = model(frame)
    annotated_frame = results[0].plot()
    out.write(annotated_frame)
cap.release()
out.release()
print("saved to: {output_video_path}")
# Out:
# 0: 640x352 3 persons, 6 cars, 1 traffic light, 220.4ms
# Speed: 9.0ms preprocess, 220.4ms inference, 12.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 persons, 5 cars, 1 traffic light, 157.6ms
# Speed: 3.0ms preprocess, 157.6ms inference, 13.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 persons, 5 cars, 253.3ms
# Speed: 6.0ms preprocess, 253.3ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 persons, 7 cars, 135.6ms
# Speed: 4.0ms preprocess, 135.6ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 persons, 4 cars, 113.7ms
# Speed: 2.0ms preprocess, 113.7ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 persons, 4 cars, 136.6ms
# Speed: 2.0ms preprocess, 136.6ms inference, 12.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 persons, 4 cars, 163.6ms
# ...
