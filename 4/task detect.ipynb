# %%
from ultralytics import YOLO
import cv2

# %%
model = YOLO('yolov8n.pt')

# %%
results = model.predict(source=r"C:\Users\DELL\Desktop\test\vibes.MOV", show=True, conf=0.4, save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/170) C:\Users\DELL\Desktop\test\vibes.MOV: 640x352 2 persons, 5 cars, 64.4ms
# video 1/1 (frame 2/170) C:\Users\DELL\Desktop\test\vibes.MOV: 640x352 2 persons, 5 cars, 95.6ms
# video 1/1 (frame 3/170) C:\Users\DELL\Desktop\test\vibes.MOV: 640x352 2 persons, 5 cars, 86.9ms
# video 1/1 (frame 4/170) C:\Users\DELL\Desktop\test\vibes.MOV: 640x352 2 persons, 5 cars, 113.8ms
# ...

# %%
from ultralytics import YOLO
import cv2
model = YOLO('yolov8n.pt')
results = model(source=r"C:\Users\DELL\Desktop\test\image1.jpg", show=True, conf=0.4, save=True)
# Out:
# image 1/1 C:\Users\DELL\Desktop\test\image1.jpg: 512x640 1 cat, 1 dog, 138.0ms
# Speed: 0.0ms preprocess, 138.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs\detect\predict6
